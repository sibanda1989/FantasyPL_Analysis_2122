# %%
import requests
import pandas as pd
import numpy as np

# %%
#fantasy premier league api url
url = 'https://fantasy.premierleague.com/api/bootstrap-static/'

#using the url to make a GET request from the API endpoint
r = requests.get(url)

#transforming the request into a JSON object
json =  r.json()

# %%
#lets have a look at the json keys
json.keys()
# Out:
# dict_keys(['events', 'game_settings', 'phases', 'teams', 'total_players', 'elements', 'element_stats', 'element_types'])

# %%
#main interest is in 3 keys, teams, element_type and elements.
#building dataframes from these keys

elements_df = pd.DataFrame(json['elements'])
element_types_df = pd.DataFrame(json['element_types'])
teams_df = pd.DataFrame(json['teams'])

# %%
teams_df.head()
# Out:
#    code  draw  form  id  loss         name  played  points  position  \
# 0     3     0  None   1     0      Arsenal       0       0         0
# 1     7     0  None   2     0  Aston Villa       0       0         0
# 2    94     0  None   3     0    Brentford       0       0         0
# 3    36     0  None   4     0     Brighton       0       0         0
# 4    90     0  None   5     0      Burnley       0       0         0
#
#   short_name  ...  team_division unavailable  win  strength_overall_home  \
# 0        ARS  ...           None       False    0                   1250
# 1        AVL  ...           None       False    0                   1100
# 2        BRE  ...           None       False    0                   1060
# 3        BHA  ...           None       False    0                   1100
# 4        BUR  ...           None       False    0                   1060
#
#    strength_overall_away  strength_attack_home  strength_attack_away  \
# ...

# %%
element_types_df.head()
# Out:
#    id  plural_name plural_name_short singular_name singular_name_short  \
# 0   1  Goalkeepers               GKP    Goalkeeper                 GKP
# 1   2    Defenders               DEF      Defender                 DEF
# 2   3  Midfielders               MID    Midfielder                 MID
# 3   4     Forwards               FWD       Forward                 FWD
#
#    squad_select  squad_min_play  squad_max_play  ui_shirt_specific  \
# 0             2               1               1               True
# 1             5               3               5              False
# 2             5               2               5              False
# 3             3               1               3              False
#
#   sub_positions_locked  element_count
# 0                 [12]             83
# 1                   []            242
# 2                   []            296
# 3                   []             93

# %%
elements_df.head()
# Out:
#    chance_of_playing_next_round  chance_of_playing_this_round    code  \
# 0                         100.0                         100.0   80201
# 1                           0.0                           0.0  115918
# 2                           0.0                           0.0   47431
# 3                           0.0                           0.0   54694
# 4                         100.0                         100.0   58822
#
#    cost_change_event  cost_change_event_fall  cost_change_start  \
# 0                  0                       0                 -5
# 1                  0                       0                  0
# 2                  0                       0                 -2
# 3                  0                       0                 -4
# 4                  0                       0                 -3
#
#    cost_change_start_fall  dreamteam_count  element_type ep_next  ...  \
# 0                       5                1             1     2.0  ...
# ...

# %%
elements_df.columns
# Out:
# Index(['chance_of_playing_next_round', 'chance_of_playing_this_round', 'code',
#        'cost_change_event', 'cost_change_event_fall', 'cost_change_start',
#        'cost_change_start_fall', 'dreamteam_count', 'element_type', 'ep_next',
#        'ep_this', 'event_points', 'first_name', 'form', 'id', 'in_dreamteam',
#        'news', 'news_added', 'now_cost', 'photo', 'points_per_game',
#        'second_name', 'selected_by_percent', 'special', 'squad_number',
#        'status', 'team', 'team_code', 'total_points', 'transfers_in',
#        'transfers_in_event', 'transfers_out', 'transfers_out_event',
#        'value_form', 'value_season', 'web_name', 'minutes', 'goals_scored',
#        'assists', 'clean_sheets', 'goals_conceded', 'own_goals',
#        'penalties_saved', 'penalties_missed', 'yellow_cards', 'red_cards',
#        'saves', 'bonus', 'bps', 'influence', 'creativity', 'threat',
#        'ict_index', 'influence_rank', 'influence_rank_type', 'creativity_rank',
# ...

# %%
#elements df contains player data so we will make a copy of it and return only some useful columns
player_df = elements_df[['first_name', 'second_name', 'team', 'element_type', 'selected_by_percent', 'now_cost', 'transfers_in', 'value_season', 'total_points', 'minutes', 'goals_scored', 'assists', 'clean_sheets', 'goals_conceded', 'bonus', 'points_per_game']]

player_df.head()
# Out:
#        first_name      second_name  team  element_type selected_by_percent  \
# 0           Bernd             Leno     1             1                 0.9
# 1      Rúnar Alex        Rúnarsson     1             1                 0.5
# 2         Willian  Borges Da Silva     1             3                 0.1
# 3  Pierre-Emerick       Aubameyang     1             4                 1.3
# 4          Cédric           Soares     1             2                 0.3
#
#    now_cost  transfers_in value_season  total_points  minutes  goals_scored  \
# 0        45         70510          2.2            10      360             0
# 1        40         19017          0.0             0        0             0
# 2        63           914          0.0             0        0             0
# 3        96        742898          4.6            44     1036             4
# 4        42         31005          5.7            24      829             0
#
# ...

# %%
element_types_df.head()
# Out:
#    id  plural_name plural_name_short singular_name singular_name_short  \
# 0   1  Goalkeepers               GKP    Goalkeeper                 GKP
# 1   2    Defenders               DEF      Defender                 DEF
# 2   3  Midfielders               MID    Midfielder                 MID
# 3   4     Forwards               FWD       Forward                 FWD
#
#    squad_select  squad_min_play  squad_max_play  ui_shirt_specific  \
# 0             2               1               1               True
# 1             5               3               5              False
# 2             5               2               5              False
# 3             3               1               3              False
#
#   sub_positions_locked  element_count
# 0                 [12]             83
# 1                   []            242
# 2                   []            296
# 3                   []             93

# %%
#merging two dfs to return a specific column, (similar to left join in SQL, vlookup in excel)
player_df1 = pd.merge(player_df, element_types_df[['id','singular_name']], left_on='element_type', right_on='id', how='left')

player_df1.head()
# Out:
#        first_name      second_name  team  element_type selected_by_percent  \
# 0           Bernd             Leno     1             1                 0.9
# 1      Rúnar Alex        Rúnarsson     1             1                 0.5
# 2         Willian  Borges Da Silva     1             3                 0.1
# 3  Pierre-Emerick       Aubameyang     1             4                 1.3
# 4          Cédric           Soares     1             2                 0.3
#
#    now_cost  transfers_in value_season  total_points  minutes  goals_scored  \
# 0        45         70510          2.2            10      360             0
# 1        40         19017          0.0             0        0             0
# 2        63           914          0.0             0        0             0
# 3        96        742898          4.6            44     1036             4
# 4        42         31005          5.7            24      829             0
#
# ...

# %%
teams_df.head()
# Out:
#    code  draw  form  id  loss         name  played  points  position  \
# 0     3     0  None   1     0      Arsenal       0       0         0
# 1     7     0  None   2     0  Aston Villa       0       0         0
# 2    94     0  None   3     0    Brentford       0       0         0
# 3    36     0  None   4     0     Brighton       0       0         0
# 4    90     0  None   5     0      Burnley       0       0         0
#
#   short_name  ...  team_division unavailable  win  strength_overall_home  \
# 0        ARS  ...           None       False    0                   1250
# 1        AVL  ...           None       False    0                   1100
# 2        BRE  ...           None       False    0                   1060
# 3        BHA  ...           None       False    0                   1100
# 4        BUR  ...           None       False    0                   1060
#
#    strength_overall_away  strength_attack_home  strength_attack_away  \
# ...

# %%
player_df = pd.merge(player_df1, teams_df[['id', 'name']], left_on='team', right_on='id')
player_df.head()
# Out:
#        first_name      second_name  team  element_type selected_by_percent  \
# 0           Bernd             Leno     1             1                 0.9
# 1      Rúnar Alex        Rúnarsson     1             1                 0.5
# 2         Willian  Borges Da Silva     1             3                 0.1
# 3  Pierre-Emerick       Aubameyang     1             4                 1.3
# 4          Cédric           Soares     1             2                 0.3
#
#    now_cost  transfers_in value_season  total_points  minutes  goals_scored  \
# 0        45         70510          2.2            10      360             0
# 1        40         19017          0.0             0        0             0
# 2        63           914          0.0             0        0             0
# 3        96        742898          4.6            44     1036             4
# 4        42         31005          5.7            24      829             0
#
# ...

# %%
player_df.drop(['team', 'id_x', 'id_y'], axis=1, inplace=True)


player_df.head()
# Out:
#        first_name      second_name  element_type selected_by_percent  \
# 0           Bernd             Leno             1                 0.9
# 1      Rúnar Alex        Rúnarsson             1                 0.5
# 2         Willian  Borges Da Silva             3                 0.1
# 3  Pierre-Emerick       Aubameyang             4                 1.3
# 4          Cédric           Soares             2                 0.3
#
#    now_cost  transfers_in value_season  total_points  minutes  goals_scored  \
# 0        45         70510          2.2            10      360             0
# 1        40         19017          0.0             0        0             0
# 2        63           914          0.0             0        0             0
# 3        96        742898          4.6            44     1036             4
# 4        42         31005          5.7            24      829             0
#
#    assists  clean_sheets  goals_conceded  bonus points_per_game singular_name  \
# ...

# %%
player_df.rename(columns={"singular_name": "position", "name": "team"}, inplace=True)

player_df.head()
# Out:
#        first_name      second_name  element_type selected_by_percent  \
# 0           Bernd             Leno             1                 0.9
# 1      Rúnar Alex        Rúnarsson             1                 0.5
# 2         Willian  Borges Da Silva             3                 0.1
# 3  Pierre-Emerick       Aubameyang             4                 1.3
# 4          Cédric           Soares             2                 0.3
#
#    now_cost  transfers_in value_season  total_points  minutes  goals_scored  \
# 0        45         70510          2.2            10      360             0
# 1        40         19017          0.0             0        0             0
# 2        63           914          0.0             0        0             0
# 3        96        742898          4.6            44     1036             4
# 4        42         31005          5.7            24      829             0
#
#    assists  clean_sheets  goals_conceded  bonus points_per_game    position  \
# ...

# %%
player_df.shape
# Out:
# (714, 17)

# %%
player_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 714 entries, 0 to 713
# Data columns (total 17 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   first_name           714 non-null    object
#  1   second_name          714 non-null    object
#  2   element_type         714 non-null    int64
#  3   selected_by_percent  714 non-null    object
#  4   now_cost             714 non-null    int64
#  5   transfers_in         714 non-null    int64
#  6   value_season         714 non-null    object
#  7   total_points         714 non-null    int64
#  8   minutes              714 non-null    int64
#  9   goals_scored         714 non-null    int64
#  10  assists              714 non-null    int64
#  11  clean_sheets         714 non-null    int64
#  12  goals_conceded       714 non-null    int64
#  13  bonus                714 non-null    int64
#  14  points_per_game      714 non-null    object
# ...

# %%
#converting player value to float
player_df['value'] = player_df.value_season.astype(float)

# %%
#dropping value_season column
player_df.drop(['value_season'], axis=1, inplace=True)

# %%
#sorting players by value
player_df.sort_values('value', ascending=False).head(10)
# Out:
#             first_name       second_name  element_type selected_by_percent  \
# 679              Conor             Coady             2                17.9
# 700               José    Malheiro de Sá             1                12.3
# 406  João Pedro Cavaco           Cancelo             2                37.2
# 371            Alisson     Ramses Becker             1                 8.3
# 32               Aaron          Ramsdale             1                20.4
# 25                 Ben             White             2                14.1
# 56             Matthew              Cash             2                 9.7
# 364               Joel             Matip             2                 4.2
# 658             Jarrod             Bowen             3                11.2
# 377              Trent  Alexander-Arnold             2                41.6
#
#      now_cost  transfers_in  total_points  minutes  goals_scored  assists  \
# ...

# %% [markdown]
# We can see that defenders and goalkeepers present the best value (points to price ratio)

# %%
#creating a pivot on value per position
pivot = player_df.pivot_table(index='position', values='value', aggfunc='mean').reset_index()

pivot.sort_values('value', ascending=False)
# Out:
#      position     value
# 0    Defender  6.876033
# 3  Midfielder  6.027703
# 1     Forward  5.090323
# 2  Goalkeeper  5.039759

# %% [markdown]
# Defenders represent the highest value, followed by midfielders

# %%
player_df['bonus'] = player_df['bonus'].astype(int)

# %%
player_df.drop(['element_type'], axis=1, inplace=True)

# %%
#to get a true reflection of positional value, lets drop players who have not played. 
#These will have 0 value, since value = points/price (and points are only awarded to those that will have played) 

player_df = player_df.loc[player_df['value'] > 0]

# %%
pivot = player_df.pivot_table(index='position', values='value', aggfunc='mean').reset_index()

pivot.sort_values('value', ascending=False)
# Out:
#      position      value
# 2  Goalkeeper  10.725641
# 0    Defender   9.401130
# 3  Midfielder   7.826316
# 1     Forward   6.575000

# %% [markdown]
# Now goalkeepers are back on top

# %%
#lets see which team provides best value

team_pivot = player_df.pivot_table(index='team', values='value', aggfunc='mean').reset_index()

team_pivot.sort_values('value', ascending=False)
# Out:
#               team      value
# 19          Wolves  10.729167
# 5          Chelsea  10.488000
# 11        Man City  10.028000
# 0          Arsenal   9.956000
# 6   Crystal Palace   9.870833
# 10       Liverpool   9.770370
# 16           Spurs   9.575000
# 18        West Ham   9.456000
# 3         Brighton   8.512500
# 4          Burnley   8.509524
# 15     Southampton   8.456000
# 12         Man Utd   8.208333
# 1      Aston Villa   7.966667
# 2        Brentford   7.785714
# 13       Newcastle   7.593103
# 9        Leicester   7.468000
# 14         Norwich   7.128000
# 8            Leeds   6.275000
# 17         Watford   6.076667
# 7          Everton   6.009677

# %%
#points per minute played, ppm

player_df['ppm'] = player_df['total_points'] / player_df['minutes']

# %%
#saving the data to a csv flat file
player_df.to_csv('fpl_data.csv', index=False)
